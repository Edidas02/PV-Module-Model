# %%
from wwo_hist import retrieve_hist_data
import glob
import pandas as pd
import os

# %%
os.chdir("Documents/GitHub/PV-Module-Model/")

# %%
"""
frequency = 24
start_date = '21-JAN-2011'
end_date = '4-MAR-2012'
api_key = '8918d442e14940ae9fa04448201507'
location_list = ['32922']

hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
"""
# Out:
# Retrieving weather data for 32922
#
#
# Currently retrieving data for 32922: from 2011-01-21 to 2011-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.811916
# Currently retrieving data for 32922: from 2011-02-01 to 2011-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:01.311465
# Currently retrieving data for 32922: from 2011-03-01 to 2011-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:02.782153
# Currently retrieving data for 32922: from 2011-04-01 to 2011-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:03.332337
# Currently retrieving data for 32922: from 2011-05-01 to 2011-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.881223
# Currently retrieving data for 32922: from 2011-06-01 to 2011-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:05.076035
# Currently retrieving data for 32922: from 2011-07-01 to 2011-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.609861
# Currently retrieving data for 32922: from 2011-08-01 to 2011-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:07.021678
# ...

# %%
"""
frequency = 24
start_date = '14-AUG-2013'
end_date = '24-SEP-2014'
api_key = '8918d442e14940ae9fa04448201507'
location_list = ['97401']

hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
"""
# Out:
# Retrieving weather data for 97401
#
#
# Currently retrieving data for 97401: from 2013-08-14 to 2013-08-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.372620
# Currently retrieving data for 97401: from 2013-09-01 to 2013-09-30
# Time elapsed (hh:mm:ss.ms) 0:00:00.926763
# Currently retrieving data for 97401: from 2013-10-01 to 2013-10-31
# Time elapsed (hh:mm:ss.ms) 0:00:01.502469
# Currently retrieving data for 97401: from 2013-11-01 to 2013-11-30
# Time elapsed (hh:mm:ss.ms) 0:00:02.068600
# Currently retrieving data for 97401: from 2013-12-01 to 2013-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.274720
# Currently retrieving data for 97401: from 2014-01-01 to 2014-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.855192
# Currently retrieving data for 97401: from 2014-02-01 to 2014-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:04.914008
# Currently retrieving data for 97401: from 2014-03-01 to 2014-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.990304
# ...

# %%
"""
frequency = 24
start_date = '20-DEC-2012'
end_date = '20-JAN-2014'
api_key = '8918d442e14940ae9fa04448201507'
location_list = ['80401']

hist_weather_data = retrieve_hist_data(api_key,
                                location_list,
                                start_date,
                                end_date,
                                frequency,
                                location_label = False,
                                export_csv = True,
                                store_df = True)
"""
# Out:
# Retrieving weather data for 80401
#
#
# Currently retrieving data for 80401: from 2012-12-20 to 2012-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.861028
# Currently retrieving data for 80401: from 2013-01-01 to 2013-01-31
# Time elapsed (hh:mm:ss.ms) 0:00:03.097722
# Currently retrieving data for 80401: from 2013-02-01 to 2013-02-28
# Time elapsed (hh:mm:ss.ms) 0:00:04.336008
# Currently retrieving data for 80401: from 2013-03-01 to 2013-03-31
# Time elapsed (hh:mm:ss.ms) 0:00:05.937198
# Currently retrieving data for 80401: from 2013-04-01 to 2013-04-30
# Time elapsed (hh:mm:ss.ms) 0:00:06.991267
# Currently retrieving data for 80401: from 2013-05-01 to 2013-05-31
# Time elapsed (hh:mm:ss.ms) 0:00:08.197205
# Currently retrieving data for 80401: from 2013-06-01 to 2013-06-30
# Time elapsed (hh:mm:ss.ms) 0:00:09.494197
# Currently retrieving data for 80401: from 2013-07-01 to 2013-07-31
# Time elapsed (hh:mm:ss.ms) 0:00:10.643957
# ...

# %%
"""
files = ["/Users/edwardxiong/Documents/GitHub/PV-Module-Model/weather-data/cocoa.csv", 
         "/Users/edwardxiong/Documents/GitHub/PV-Module-Model/weather-data/golden.csv",  
         "/Users/edwardxiong/Documents/GitHub/PV-Module-Model/weather-data/eugene.csv"]
"""
# Out:
# ['/Users/edwardxiong/Documents/GitHub/PV-Module-Model/weather-data/cocoa.csv', '/Users/edwardxiong/Documents/GitHub/PV-Module-Model/weather-data/golden.csv', '/Users/edwardxiong/Documents/GitHub/PV-Module-Model/weather-data/eugene.csv']

# %%
"""dfs = []
for file in files:
    dfs.append(pd.read_csv(file))
df = pd.concat(dfs)
df.to_csv("weather-data.csv")
"""

# %%
df = pd.read_csv("weather-data.csv")
df
# Out:
#       Unnamed: 0   date_time  maxtempC  mintempC  totalSnow_cm  sunHour  \
# 0              0  2011-01-21        20        17           0.0      5.2
# 1              1  2011-01-22        16         9           0.0     10.4
# 2              2  2011-01-23        15         6           0.0     10.4
# 3              3  2011-01-24        20        13           0.0      8.4
# 4              4  2011-01-25        23        18           0.0      5.2
# ...          ...         ...       ...       ...           ...      ...
# 1208         402  2014-09-20        35        12           0.0     11.6
# 1209         403  2014-09-21        28        11           0.0     11.6
# 1210         404  2014-09-22        24        11           0.0     10.2
# 1211         405  2014-09-23        25        12           0.0     10.2
# 1212         406  2014-09-24        16        12           0.0      6.0
#
#       uvIndex  moon_illumination     moonrise   moonset  ... WindGustKmph  \
# ...
